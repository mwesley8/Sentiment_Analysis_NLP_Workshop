# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
unemployment = pd.read_csv('http://data-analytics.zybooks.com/unemployment.csv')

# %%
plt.title("United States Unemployment Rate", fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Percent of labor force')
plt.plot(unemployment['Year'], unemployment['Value'])
plt.show()

# %%
# SNS provided dataset
crashes = sns.load_dataset("car_crashes")
# Create a dataframe with the first five entries
df = crashes.loc[range(5)]
# Output the dataframe to the user
df
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
# Figure and axix variables
f, ax = plt.subplots()

#plot total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=df,
            label="Total", color="b")

# plot crashes related to speeding
sns.set_color_codes("muted")
sns.barplot(x="speeding", y="abbrev", data=df,
            label="Speeding-related", color="b")

# title
plt.title('Speeding-related automobile collisions', fontsize=20)

# legend
ax.legend(ncol=1, loc="lower right")
ax.set(xlim=(0, 28), ylabel="State", xlabel="Automobile collisions (per billion miles)");

# saves the image
#plt.savefig("stacked.png")

# shows the image
plt.show()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
print(titanic['age'].mean())
print(titanic['age'].median())
print(titanic['age'].min())
# Out:
# 29.69911764705882
# 28.0
# 0.42

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic[['sex', 'survived']].head()
# Out:
#       sex  survived
# 0    male         0
# 1  female         1
# 2  female         1
# 3  female         1
# 4    male         0

# %%
# Creates a dataframe with the first five rows
titanic[:5]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Creates a dataframe with only the passengers with an age less than 30
titanic[titanic.age <= 30]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 2    woman       False  NaN  Southampton   yes   True
# 7    child       False  NaN  Southampton    no  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 883    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [409 rows x 15 columns]

# %%
# Creating a dataframe with the length and specified columns
titanic.loc[0:5, ['fare', 'embark_town']]
# Out:
#       fare  embark_town
# 0   7.2500  Southampton
# 1  71.2833    Cherbourg
# 2   7.9250  Southampton
# 3  53.1000  Southampton
# 4   8.0500  Southampton
# 5   8.4583   Queenstown

# %%
# Creates a data frame
df = pd.DataFrame({'Student': {0: "Michael", 1: "Arushi", 2: "Roberta",
                   3: "Michael", 4: "Arushi", 5: "Roberta"},
                   'Score': {0: 90, 1: 98, 2: 92, 3: 90, 4: 98, 5: 92},
                   'Date': {0: "2018-01-03", 1: "2018-01-03", 2: "2018-01-03", 3: "2018-01-13",
                    4: "2018-01-13", 5: "2018-01-13"}},
                    columns=['Date','Student','Score'])

# %%
df
# Out:
#          Date  Student  Score
# 0  2018-01-03  Michael     90
# 1  2018-01-03   Arushi     98
# 2  2018-01-03  Roberta     92
# 3  2018-01-13  Michael     90
# 4  2018-01-13   Arushi     98
# 5  2018-01-13  Roberta     92

# %%
# Long form to wide form or vice versa
df.pivot(index = 'Date', columns='Student', values='Score')
# Out:
# Student     Arushi  Michael  Roberta
# Date
# 2018-01-03      98       90       92
# 2018-01-13      98       90       92

# %%
# sets the style of the bar charts
sns.set(style="whitegrid", color_codes=True)

# title
plt.title('HMS Titanic passengers by class', fontsize=20)

# plots a vertical bar chart
sns.countplot(x="class", color="b", data=titanic);

# saves the image
#plt.savefig("verticalbarchart.png")

# shows the image
plt.show()

# %%
# sets the style of the bar charts
sns.set(style="whitegrid", color_codes=True)

# title
plt.title('Titanic survivors and deaths by class', fontsize=20)

# generates a vertical bar chart
sns.countplot(x="class", hue="survived", palette="dark:b", data=titanic);

# saves the image
#plt.savefig("groupedbarchart.png")

# shows the image
plt.show()

# %%
# loads the titanic dataset
df = sns.load_dataset("titanic")

# counts the number of passengers for each class
a = df[df.pclass == 1]["pclass"].count()
b = df[df.pclass == 2]["pclass"].count()
c = df[df.pclass == 3]["pclass"].count()

# data to plot
labels = 'First', 'Second', 'Third'
sizes = [a, b, c]

# plot
plt.pie(sizes, labels=labels, autopct='%1.1f%%')

# title
plt.title('Titanic passengers by class', fontsize=20)

# legend
patches, texts = plt.pie(sizes)
plt.legend(patches, labels, loc="lower right")

# produces a perfectly circular chart
plt.axis('equal')

# saves the image
#plt.savefig("piechart.png")

# shows the image
plt.show()

# %%
# data to plot
a = df[df.survived == 1]["survived"].count()
b = df[df.survived == 0]["survived"].count()

# creates a tuple of the categories
explodeTuple = (0.1, 0.0)

# data to plot
labels = 'Survived', 'Did not survive'
sizes = [a, b]

# plot
plt.pie(sizes, labels=labels, autopct='%1.1f%%', explode = explodeTuple)

# title
plt.title('Survivors of the Titanic', fontsize=20)

# produces a perfectly circular chart
plt.axis('equal')

# saves the image
#plt.savefig("explodedpiechart.png")

# shows the image
plt.show()

# %%
# loads the necessary libraries
import numpy as np

# creates the data points
x1 = np.array([0, 5, 3, 4, 7, 8, 10])
y1 = np.array([5, 2, 5, 15, 27, 15, 31])

# plot
sns.regplot(x = x1, y = y1)

# saves the image
#plt.savefig("scatterplot.png")

# shows the image
plt.show()

# %%
# loads the iris data set
df = sns.load_dataset("iris")

# title
plt.title('Petal length and width of iris', fontsize=20)

# plot
sns.regplot(x = df["petal_length"], y = df["petal_width"], ci = None, fit_reg = False);

# saves the image
#plt.savefig("irisscatterplot.png")

# shows the image
plt.show()

# %%
# title
plt.title('Fares paid by passengers of the Titanic by deck', fontsize=20)

# plot
sns.stripplot(x = "deck",  y= "fare", data = titanic, jitter = False);

# saves the image
#plt.savefig("titanicstripplot.png")

# shows the image
plt.show()

# %%
# loads the titanic dataset
titanic = sns.load_dataset("titanic")

# title
plt.title('Fares paid by passengers of the Titanic by deck', fontsize=20)

# plot
sns.swarmplot(x = "deck", y = "fare", hue = "sex", data = titanic);

# saves the image
#plt.savefig("titanicswarmplot.png")

# shows the image
plt.show()
